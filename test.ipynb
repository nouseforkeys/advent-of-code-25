# %%
import logging
from pathlib import Path

from advent_of_code_utils.advent_of_code_utils import (
    parse_from_file,
    ParseConfig as PC
)

log = logging.getLogger("test notebook")
logging.basicConfig(level=logging.INFO)

input_file = Path("test.txt")
parser = PC("\n", PC(",", int))
test_input = parse_from_file(input_file, parser)
print(f"{test_input=}")
# Out:
# INFO:advent_of_code_utils.py:2 items loaded from "test.txt"
# test_input=[[1, 2, 3], [4, 5, 6]]

# %% [markdown]
# Coolio - it still works!
